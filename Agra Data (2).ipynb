# %%
# Importing libraries
import requests
import numpy as np
import pandas as pd
from datetime import datetime as dt
import calendar

# %%
header={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}
url="https://vegetablemarketprice.com/api/data/market/agra/chartdata?start=2022-01-26&end=2023-05-10&vegIds=onionBig,onionSmall,tomato,greenChili,beetroot,potato,plantain,amaranthLeaves,amla,ashGourd,babyCorn,bananaFlower,capsicum,bitterGourd,bottleGourd,butterBeans,broadBeans,cabbage,carrot,cauliflower,clusterBeans,coconut,colocasiaLeaves,colocasia,corianderLeaves,corn,cucumber,curryLeaves,dillLeaves,drumsticks,brinjal,brinjalBig,elephantYam,fenugreekLeaves,frenchBeans,garlic,ginger,onionGreen,greenPeas,ivyGourd,lemon,mangoRaw,mintLeaves,mushroom,mustardLeaves,ladiesFinger,pumpkin,radish,ridgeGourd,shallot,snakeGourd,sorrelLeaves,spinach,sweetPotato"
res=requests.get(url, headers=header)
data=res.json()
# print(data)

# %%
vn=[]
veg=[]
d=data['columns']
dat=[]
mp=[]
rp=[]
smp=[]
u=[]
for i in data['columnMapping']:
    vn.append(i['vegName'])
l=len(vn)
l1=len(d)
for i in range(l): #loop on vegetable name
    for j in range(l1): #loop on each date
        rp.append(data["data"][i]['data'][j]['retailPrice'])
        veg.append(vn[i])
        dat.append(d[j])
        mp.append(data["data"][i]['data'][j]['y'])
        u.append(data["data"][i]['data'][j]['units'])
        smp.append(data["data"][i]['data'][j]['shopingMallPrice'])
        # print(vn[i],d[j],data["data"][i]['data'][j]['y'],data["data"][i]['data'][j]['units'],data["data"][i]['data'][j]['shopingMallPrice'],data["data"][i]['data'][j]['retailPrice'])
    print(len(rp),len(veg),len(dat),len(mp),len(u),len(smp))
# Out:
# 470 470 470 470 470 470
# 940 940 940 940 940 940
# 1410 1410 1410 1410 1410 1410
# 1880 1880 1880 1880 1880 1880
# 2350 2350 2350 2350 2350 2350
# 2820 2820 2820 2820 2820 2820
# 3290 3290 3290 3290 3290 3290
# 3760 3760 3760 3760 3760 3760
# 4230 4230 4230 4230 4230 4230
# 4700 4700 4700 4700 4700 4700
# 5170 5170 5170 5170 5170 5170
# 5640 5640 5640 5640 5640 5640
# 6110 6110 6110 6110 6110 6110
# 6580 6580 6580 6580 6580 6580
# 7050 7050 7050 7050 7050 7050
# 7520 7520 7520 7520 7520 7520
# 7990 7990 7990 7990 7990 7990
# 8460 8460 8460 8460 8460 8460
# 8930 8930 8930 8930 8930 8930
# 9400 9400 9400 9400 9400 9400
# 9870 9870 9870 9870 9870 9870
# 10340 10340 10340 10340 10340 10340
# 10810 10810 10810 10810 10810 10810
# 11280 11280 11280 11280 11280 11280
# 11750 11750 11750 11750 11750 11750
# 12220 12220 12220 12220 12220 12220
# 12690 12690 12690 12690 12690 12690
# 13160 13160 13160 13160 13160 13160
# 13630 13630 13630 13630 13630 13630
# ...

# %%
col={
    "Date":dat,
    "Vegetable_Name":veg,
    "Units":u,
    "Market_Price":mp,
    "Retail_Price":rp,
    "Shoping_Mall_Price":smp
}
dF=pd.DataFrame(col)
path='C:/Users/ARGHYA/Downloads/Project/data_agra.csv'
dF.to_csv(path,index=False)

# %%
path="C:/Users/ARGHYA/Downloads/Project/data_agra.csv"

# %%
df_agra=pd.read_csv(path)
df_agra
# Out:
#              Date Vegetable_Name Units  Market_Price Retail_Price  \
# 0      2022-01-26      Onion Big   1kg            37      43 - 47
# 1      2022-01-27      Onion Big   1kg            37      43 - 47
# 2      2022-01-28      Onion Big   1kg            37      43 - 47
# 3      2022-01-29      Onion Big   1kg            37      43 - 47
# 4      2022-01-30      Onion Big   1kg            37      43 - 47
# ...           ...            ...   ...           ...          ...
# 25375  2023-05-06   Sweet Potato   1kg            38      44 - 48
# 25376  2023-05-07   Sweet Potato   1kg            40      46 - 51
# 25377  2023-05-08   Sweet Potato   1kg            40      46 - 51
# 25378  2023-05-09   Sweet Potato   1kg            40      46 - 51
# 25379  2023-05-10   Sweet Potato   1kg            40      46 - 51
#
#       Shoping_Mall_Price
# 0                44 - 61
# 1                44 - 61
# 2                44 - 61
# 3                44 - 61
# 4                44 - 61
# ...

# %%
df_agra.isnull().sum()
# Out:
# Date                  0
# Vegetable_Name        0
# Units                 0
# Market_Price          0
# Retail_Price          0
# Shoping_Mall_Price    0
# dtype: int64

# %%
df_agra.duplicated().sum()
# Out:
# 0

# %%
Retail_Price_low_list=[]
Retail_Price_high_list=[]
for m in df_agra['Retail_Price'].str.split(' - '):
    for i in range(2):
        if i==0:
            Retail_Price_low_list.append(m[i])
        else:
            Retail_Price_high_list.append(m[i])

# %%
df_agra['Retail_Price_low']=Retail_Price_low_list
df_agra['Retail_Price_high']=Retail_Price_high_list

# %%
df_agra['Retail_Price_low']=df_agra['Retail_Price_low'].astype(np.int64)
df_agra['Retail_Price_high']=df_agra['Retail_Price_high'].astype(np.int64)

# %%
df_agra['Average_Retail_Price']=(df_agra['Retail_Price_low']+df_agra['Retail_Price_high'])/2

# %%
df_agra.drop(['Retail_Price','Retail_Price_high','Retail_Price_low'], axis=1,inplace=True)

# %%
Shoping_Mall_Price_low_list=[]
Shoping_Mall_Price_high_list=[]
for m in df_agra['Shoping_Mall_Price'].str.split(' - '):
    for i in range(2):
        if i==0:
            Shoping_Mall_Price_low_list.append(m[i])
        else:
            Shoping_Mall_Price_high_list.append(m[i])

# %%
df_agra['Shoping_Mall_Price_low']=Shoping_Mall_Price_low_list
df_agra['Shoping_Mall_Price_high']=Shoping_Mall_Price_high_list

# %%
df_agra['Shoping_Mall_Price_low']=df_agra['Shoping_Mall_Price_low'].astype(np.int64)
df_agra['Shoping_Mall_Price_high']=df_agra['Shoping_Mall_Price_high'].astype(np.int64)

# %%
df_agra['Average_Shoping_Mall_Price']=(df_agra['Shoping_Mall_Price_low']+df_agra['Shoping_Mall_Price_high'])/2

# %%
df_agra.drop(['Shoping_Mall_Price','Shoping_Mall_Price_high','Shoping_Mall_Price_low'], axis=1,inplace=True)

# %%
agra_veg_name=df_agra.groupby(['Vegetable_Name'],as_index=False).agg({"Market_Price":"mean" , \
"Average_Retail_Price":"mean", "Average_Shoping_Mall_Price":"mean"})
agra_veg_name.head()
# Out:
#     Vegetable_Name  Market_Price  Average_Retail_Price  \
# 0  Amaranth Leaves     11.787234             14.286170
# 1             Amla     61.510638             74.523404
# 2        Ash gourd     22.906383             27.672340
# 3        Baby Corn     59.127660             71.565957
# 4    Banana Flower     16.719149             20.275532
#
#    Average_Shoping_Mall_Price
# 0                   16.847872
# 1                   87.672340
# 2                   32.647872
# 3                   84.285106
# 4                   23.789362

# %%
df_agra['year'] = pd.DatetimeIndex(df_agra['Date']).year
df_agra['month'] = pd.DatetimeIndex(df_agra['Date']).month

# %%
agra_veg_name_month_year=df_agra.groupby(['Vegetable_Name', 'year','month'],as_index=False).agg({"Market_Price":"mean" , \
"Average_Retail_Price":"mean", "Average_Shoping_Mall_Price":"mean"})
agra_veg_name_month_year.head(50)
# Out:
#      Vegetable_Name  year  month  Market_Price  Average_Retail_Price  \
# 0   Amaranth Leaves  2022      1     14.000000             16.833333
# 1   Amaranth Leaves  2022      2     15.071429             18.250000
# 2   Amaranth Leaves  2022      3     15.709677             19.129032
# 3   Amaranth Leaves  2022      4     16.300000             19.883333
# 4   Amaranth Leaves  2022      5     14.064516             17.032258
# 5   Amaranth Leaves  2022      6     10.833333             13.216667
# 6   Amaranth Leaves  2022      7      8.516129             10.241935
# 7   Amaranth Leaves  2022      8      8.741935             10.500000
# 8   Amaranth Leaves  2022      9      8.866667             10.400000
# 9   Amaranth Leaves  2022     10      9.000000             10.758065
# 10  Amaranth Leaves  2022     11      9.166667             10.966667
# 11  Amaranth Leaves  2022     12     10.322581             12.532258
# 12  Amaranth Leaves  2023      1     11.645161             14.290323
# ...

# %%
agra_veg_name.to_csv('C:/Users/ARGHYA/Downloads/Project/agra_veg_name.csv',index=False)
agra_veg_name_month_year.to_csv('C:/Users/ARGHYA/Downloads/Project/agra_veg_name_month_year.csv',index=False)
